# %%
def github() -> str:
    """
    This function returns a link to the GitHub repository containing solutions.

    Returns:
        str: The URL to the GitHub repository.
    """
    return "https://github.com/anasfathul/ECON481/blob/main/ECON481_HW5.py"

# %%
# DESCRIPTION

# %%
import pandas as pd

# %%
from bs4 import BeautifulSoup
import requests

def scrape_code(url: str) -> str:
    """
    This function takes as its argument a lecture’s URL on the course website.
    It will returns a string containing all the python code in the lecture formatted
    in such a way that we could save it as a python file and run it without syntax issues.
    """

    # Send a request to the URL
    response = requests.get(url)
    response.raise_for_status()  # Check for a successful request

    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Initialize an empty string to hold all Python code
    python_code = ''

    # Find all <code> tags with class "sourceCode python"
    code_blocks = soup.find_all('code', class_='sourceCode python')

    # Iterate over each code block and extract the text, stripping unwanted text if necessary
    for code in code_blocks:
        # Retrieve text and strip leading/trailing whitespace
        code_text = code.get_text().strip()
        
        # Further processing to filter out unwanted snippets or lines
        lines = code_text.split('\n')
        relevant_lines = [line for line in lines if not line.strip().startswith('%')]  # Example condition to filter lines
        
        # Join filtered lines and add to the final Python code string
        python_code += '\n'.join(relevant_lines) + '\n'

    return python_code.strip()  # Remove any extra newlines at the end

# %%
# URL of the lecture page
lecture_url = "https://lukashager.netlify.app/econ-481/01_intro_to_python#/strings"
print(scrape_code(lecture_url))
# Out:
# print('Peanut Butter' + 'Jelly')
# str_list = ['I', 'love', 'UW']
# ' '.join(str_list)
# month = 'April'
# f'The month is {month}.'
# var = 2
# var is None
# type(2) is str
# isinstance(var, int)
# my_list = ['a', 'b', 'c']
# print(my_list)
# my_new_list = [x + '_new' for x in my_list]
# my_new_list
# types_list = ['a', 1, 2., False, None]
# [type(x) for x in types_list]
# my_list[0]
# my_list[-1]
# my_list[:2]
# my_list[2:]
# my_dict = {
#     'string': 'a',
#     'int': 1,
#     'list': my_list
# }
# my_dict
# my_dict['string']
# my_dict.keys()
# list_len = len(my_list)
# idx_seq = range(list_len)
# my_new_dict = {x: my_list[x] for x in idx_seq}
# my_new_dict
# list_len == max(idx_seq)
# my_dict['string'] = 55
# my_dict
# my_tuple = ('a','b','c')
# my_tuple[1] = 'z'
# a,b = (1,2)
# a+b
# my_newer_list = []
# for list_element in my_list:
#     my_newer_list.append(list_element + '_new')
# my_newer_list
# my_sum = 0
# for num in range(1,6):
#     my_sum += num
# my_sum
# my_sum = 0
# n = 0
# while my_sum <= 2024:
#     n += 1
#     my_sum += n
# n, my_sum
# my_sum = 0
# n = 0
# while my_sum + (n+1) <= 2024:
#     n += 1
#     my_sum += n
# n, my_sum
# a_mixed_list = [1, 5, '2', 4, '12', '02']
# out = 0
# for i in range(len(a_mixed_list)):
#     out += a_mixed_list[i]
# out
# for i in range(len(a_mixed_list)):
#     if isinstance(a_mixed_list[i], str):
#         out += float(a_mixed_list[i])
#     else:
#         out += a_mixed_list[i]
# out
# data_list = [10, 20, 30, 15, 25]
# label_list = ['red', 'green', 'blue', 'red', 'green']
# red_sum, green_sum, blue_sum = 0,0,0
# for i in range(len(data_list)):
#     if label_list[i] == 'red':
#         red_sum += data_list[i]
#     elif label_list[i]  == 'green':
#         green_sum += data_list[i]
#     else:
#         blue_sum += data_list[i]
# red_sum, green_sum, blue_sum
# x = 0
# if x < 0:
#     print("negative!")
# elif x == 0:
#     # TODO: put something smart here
#     pass
# else:
#     print("positive!")
# my_sum = 0
# n = 0
# for i in range(2024):
#     if my_sum > 2024-i:
#         n += i-1
#         break
#     my_sum += i
# n, my_sum
# n = 5
# n_fac = 1
# for i in range(1,n+1):
#     n_fac *= i
# n_fac
# k = 3
# n_minus_k_fac = 1
# for i in range(1,n-k+1):
#     n_minus_k_fac *= i
# n_choose_k = 1
# for i in range(k+1, n+1):
#     n_choose_k *= i
# n_choose_k /= n_minus_k_fac
# n_choose_k
# def square(x):
#     return x**2
#
# square(2)
# def square(x):
#     """
#     This function takes as input a scalar and outputs the scalar squared.
#     """
#     return x**2
#
# square(2)
# def square(x: float) -> float:
#     """
#     This function takes as input a scalar and outputs the scalar squared.
#     """
#     return x**2
#
# square(2)
# def linear_function(x: float, m: float, b: float) -> float:
#     """
#     Given the slope (m) and intercept (b) of a line, calculate
#     the y coordinate corresponding to x.
#     """
#     return m*x + b
#
# linear_function(x=3., m=-1., b=0.)
# def linear_function(x: float, m: float=-1, b: float=0) -> float:
#     """
#     Given the slope (m) and intercept (b) of a line, calculate
#     the y coordinate corresponding to x.
#     """
#     return m*x + b
#
# linear_function(3.)
# from datetime import datetime, date, time, timedelta
# dt = datetime(2011, 10, 29, 20, 30, 21)
# dt.day
# dt.minute
# dt.date()
# dt.time()
# dt.strftime("%Y-%m-%d %H:%M")
# datetime.strptime("20091031", "%Y%m%d")
# dt2 = datetime(2011, 11, 15, 22, 30)
# delta = dt2 - dt
# delta
# dt + delta
# monday = datetime(2024, 3, 25)
# wednesday = datetime(2024, 3, 27)
# week = timedelta(days=7)
# class_dates = []
#
# while wednesday < datetime(2024, 5, 31):
#     class_dates.append(monday)
#     class_dates.append(wednesday)
#     monday += week
#     wednesday += week
#
# [x.strftime("%Y-%m-%d") for x in class_dates]
# # some_module.py
# PI = 3.14159
#
# def f(x):
#     return x + 2
#
# def g(a, b):
#     return a + b
# import some_module
# result = some_module.f(5)
# pi = some_module.PI
# from some_module import g, PI
# result = g(5, PI)
# from some_module import *
# import some_module as sm
# from some_module import PI as pi, g as gf
#
# r1 = sm.f(pi)
# r2 = gf(6, pi)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# Collect all unique tags
tags = {tag.name for tag in soup.find_all()}

# Print the list of unique tags
print(tags)
# Out:
# {'strong', 'aside', 'style', 'html', 'meta', 'ul', 'sup', 'a', 'link', 'p', 'title', 'script', 'button', 'ol', 'section', 'div', 'h1', 'img', 'li', 'em', 'h2', 'i', 'pre', 'code', 'nav', 'span', 'body', 'blockquote', 'head'}
